# %%
import pandas as pd
import pickle

# Function to load and inspect pickle files
def load_and_inspect(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

# Load and inspect the data files
train_infor_his = load_and_inspect('./train/train_infor_his')
val_id_history = load_and_inspect('./val/val_id_history')
val_interaction = load_and_inspect('./val/val_interaction')
train_interaction = load_and_inspect('./train/train_infor_his')
news_information = load_and_inspect('./news_infor')
test_information_history = load_and_inspect('./test/test_infor_his')
test_news_information = load_and_inspect('./test/test_news_infor')
test_interaction = load_and_inspect('./test/test_interaction')

print("news_information:", list(news_information.items())[:10])
print("train_infor_his:", list(train_infor_his.items())[:5])
print("train_interaction:", list(train_interaction.items())[:5])
print("val_id_history:", list(val_id_history.items())[:10])
print("val_interaction:", list(val_interaction)[:10])
print("test_information_history:", list(test_information_history.items())[:5])
print("test_news_information:", list(test_news_information.items())[:5])
print("test_interaction:", list(test_interaction)[:5])
# Out:
# news_information: [('3037230', "Ishockey-spiller: Jeg troede jeg skulle dø ISHOCKEY: Ishockey-spilleren Sebastian Harts håber stadig, at karrieren kan fortsætte i USA, efter han fik maven skåret op på diskotek Ambitionerne om at komme til USA og spille ishockey har 21-årige Sebastian Harts stadig.\nMen den tidligere Rødovre-spillere var tæt på ikke kun at miste sine sportslige ambitioner, men også livet, da han var på det forkerte sted på det forkerte tidspunkt.\nStedet var Club Mirage ved Boltens Gård i København, og tidspunktet var ved to-tiden natten til søndag 3. august.\nSammen med kæresten gennem de seneste fem år, Marie, og hendes veninde var de netop ankommet til diskoteket, da Sebastian Harts stødte ind i en person, som han ikke kendte.\n- Han gik ind i mig. Vi kom i diskussion, og jeg sagde o.k., da han foreslog, vi kunne ordne 'det' udenfor. Men vi kom på talefod igen, og han gav mig hånden og gik, husker Sebastian Harts, som i dag er hjemme og efter omstændighederne har det godt, efter det knivoverfald, som fulgte nogle minutter senere.\nSTORT SLAGSMÅL\nSebastian Harts var inde på diskoteket på vej hen for at lykønske en ven med fødselsdagen, da fire-fem fyre, blandt andet ham, der få minutter tidligere 'gav hånd', sprang på ham.\n- Det udviklede sig til et stort slagsmål på dansegulvet. De slog med en flaske, og jeg slog igen. Folk fløj til side.\n- Godt nok er jeg veltrænet, men Supermand er jeg ikke, og da jeg pludselig så to knive, tænkte jeg bare på at komme væk. Men en af fyrene nåede mig, og pludselig mærkede jeg en varme i mellemgulvet. Da jeg løftede op i trøjen, stod jeg pludselig med mine indvolde i hånden, husker Sebastian Harts.\n- Der var masser af mennesker, og alle gik i panik. Og jeg tænkte, jeg skulle dø. Heldigvis kom min kæreste og mine venner, men jeg turde ikke lægge mig ned, men efterhånden som vi ventede på ambulancen, var jeg tæt på at besvime.\n- Ja, du sagde ikke så meget. Du var, ligesom alle os andre, nærmest i chok over det, der var sket, siger Marie, der lytter i baggrunden, da Sebastian Harts fortæller sin historie.\nDet viste sig senere på Rigshospitalet, hvor Sebastian Harts var indlagt i en uge, at han havde været heldig.\nKnivstikkeren, en mand af udenlandsk herkomst, havde brugt en kniv med et blad på 14 centimeter, og han havde lavet et stort snit på langs af maven. Politiet anholdt efter knivdrabet to personer. Den ene blev løsladt efter forhøret, mens den anden blev varetægtsfængslet.\nEN CHANCE MERE\n- Knivbladet havde 'kun' ridset tyndtarmen. En centimeter til højre eller til venstre, og det havde set meget sort ud, så jeg har da været heldig.\n- Overfaldet har i hvert fald lært mig meget. Jeg føler, jeg har fået en chance mere. Det var en slem forskrækkelse, men i dag værdsætter jeg livet meget mere. At vågne op om morgenen med Marie ved siden af er virkelig noget, jeg glæder mig over. Jeg er blevet gladere for livet.\n- Næste gang jeg støder ind i en person, som jeg ikke kender, vender jeg mig bare om og går. Det hjælper ikke at spille helt. Jeg vil gerne undgå problemer. Vil gerne have en familie med børn, siger Sebastian Harts, der ikke er blevet konfronteret med sine overfaldsmænd.\n- Jeg vil helst ikke tænke mere på den episode. Jeg håber, politiet ordner resten. Jeg har i hvert fald ikke lyst til at få yderligere problemer, siger Sebastian Harts, der ikke er bange for at gå i byen.\n- Nu har det ikke været aktuelt. Jeg er slet ikke klar til at gå i byen endnu, men ved hjælp af mine rigtige gode venner, og min familie har jeg fået snakket episoden igennem, og derfor har jeg ikke brug for en psykolog.\nFRIT LEJDE HJÆLPER IKKE\nSebastian Harts mener ikke, at man i fremtiden vil se færre knivoverfald i København.\n- Vores hovedstad har vokset sig til en storby. Mange etniske grupper er presset ind i byen. Nogle af disse mennesker vil åbenbart beskytte sig med knive, så jeg tror ikke, at aktionen med frit lejde til folk med knive vil hjælpe, siger Sebastian Harts, der sta ...
# train_infor_his: [('13538', ['Coop nedlægger 180 stillinger efter historisk underskud', 'Flere hundrede danske fodboldbaner skal laves om', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Giga-handel går i vasken', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Kaos i Brøndby: Forhandlinger brudt sammen', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Ikonisk café drejer nøglen om', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Efter brat afsked: Mister 700.000 seere', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Grisetransport væltet og brudt i brand', 'Dansktalende kvinde i syrisk fangelejr: - Det er ren overlevelse', 'Sigtelse: Mand holdt ung kvinde fanget og slog hende', 'Konkurs: Umådeligt ked af det', 'Gældsstyrelsen udbetaler godtgørelse: 57.750 kroner pr. person', 'Fire personer tiltalt i Frank-sagen', 'Tv-vært Jerry Springer er død', 'Ærlig McD: Færre fritter', 'EU strammer grebet: Disse 19 giganter bliver ramt', 'Kongehuset bekræfter: Nu sker det endelig', "Sommeren i Københavns Lufthavn kan blive 'kaotisk'", 'Massivt til stede: 17-årig knivstukket', 'Løn-amok: Nu bliver de vrede', 'Dramatisk udvikling i vildmarken: Kommer med advarsel', 'Iran beslaglægger olietanker', 'Benzinudslip i Skagen', 'Ofre for fagbossen: - Hendes hånd klapper mig tre gange på røven', 'Tunge i røven: Kaos før Parken', 'Mindst 25 mister livet i luftangreb mod flere mål i Ukraine', 'Pengene ruller ind: Morten Hee har solgt sin lejlighed', 'Putins spritrute: Steget 120 procent', 'FH hasteindkalder: Lizette Risgaard anklages for upassende adfærd', 'Rockband genfødt efter 24 år', 'Pengeregn: Nu modtager særlig gruppe 5000 kroner', 'Sanne føler sig skamklippet: Vred på produktionen', 'Efter dårlig anmeldelse: Nu svarer han igen', 'Efter energikrise: Energikoncernen Andel mangedoblede sit overskud sidste år', 'Familie: Lige nu er der mange tanker', 'Udskyder undskyldning', 'Udskyder undskyldning', 'Pludselig ændring: Dommen er udsat', 'Blindt ind til kvalifikation: F1-racer i brand', 'Nyt om banegårdsaktion: Fire anholdt', 'HK overvejer ekstraordinær kongres om FH-formands fremtid', 'Skimmellignende væsker: Sur smiley til Netto', 'Anmeldelse om mand med gevær: Hold jer inden døre', "'Beck'-stjernen Stina Rautelin er død", 'Bygning overtændt: Tilkalder assistance', 'Lizette Risgaard går på orlov', 'Efter tyve år: Madonna udgiver skrottet musikvideo', '60-årig sigtet for hærværksbølge mod biler', 'Sælger 150 år gammel ejendom for to kroner', 'Mænd tiltalt for at planlægge knivangreb på gravid kvinde', 'Nyt overfald får christianitter til at frygte reel bandekrig', 'To kæmpe shows samme år: Sådan undgår jeg stress', 'Officielt: Vender tilbage i ikonisk rolle', 'Kovending: Dropper kæmpebøde til supermarked', 'Prinsessens nye titel: Ikke tjenstgørende', 'LIVE: FH holder krisemøde efter gramse-sager', 'Chok i kirkehus: To indbrud på to dage', 'Arla: Kæmpe prisfald på vej', 'FH indkalder til nyt krisemøde', 'Overrasker i retten: Bryder ud i sang', 'Nikolaj Jacobsen forlænger til 2030', 'Efter 25 år: Menneskelige rester identificeret', 'Søger vidner: 15-årig overfaldet', 'Harry Potter-stjerne gravid', 'Rystet storby: - Til at græde over', 'LIVE: FH holder krisemøde efter gramse-sager', "Minister: Slut med 'lovlig hash'", 'Brand i lejlighed i København', 'Amerikaner i Ukraine: Det er mere intenst end krigen mod terror', 'Stiktosset på rival: - Pikhoved', 'Mistede ufødt barn: Åbner op om sorgen', 'Politiets foto-fup: De må slet ikke', 'Konflikt mellem grupper af unge mænd førte til knivstik', 'To civile dræbt i hævdet ukrainsk angreb på russisk jord', 'Mary Fonden bløder millioner: Stort aktiesmæk', 'Bekræfter: Blev advaret i august 2021', 'Klimaramt landsby i Fiji forsøger at råbe verdensledere op', 'Kønsløs diva i Royal Arena', '- Faldt som en sten', 'Mystisk: Mangler 14 kvadratmeter', 'To personer bragt til hospitalet efter skyderi i Västerås', 'Åbner op om diagnose: Renser stearinlys om n ...
# train_interaction: [('13538', ['Coop nedlægger 180 stillinger efter historisk underskud', 'Flere hundrede danske fodboldbaner skal laves om', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Giga-handel går i vasken', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Kaos i Brøndby: Forhandlinger brudt sammen', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Ikonisk café drejer nøglen om', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Efter brat afsked: Mister 700.000 seere', 'Coop nedlægger 180 stillinger efter historisk underskud', 'Grisetransport væltet og brudt i brand', 'Dansktalende kvinde i syrisk fangelejr: - Det er ren overlevelse', 'Sigtelse: Mand holdt ung kvinde fanget og slog hende', 'Konkurs: Umådeligt ked af det', 'Gældsstyrelsen udbetaler godtgørelse: 57.750 kroner pr. person', 'Fire personer tiltalt i Frank-sagen', 'Tv-vært Jerry Springer er død', 'Ærlig McD: Færre fritter', 'EU strammer grebet: Disse 19 giganter bliver ramt', 'Kongehuset bekræfter: Nu sker det endelig', "Sommeren i Københavns Lufthavn kan blive 'kaotisk'", 'Massivt til stede: 17-årig knivstukket', 'Løn-amok: Nu bliver de vrede', 'Dramatisk udvikling i vildmarken: Kommer med advarsel', 'Iran beslaglægger olietanker', 'Benzinudslip i Skagen', 'Ofre for fagbossen: - Hendes hånd klapper mig tre gange på røven', 'Tunge i røven: Kaos før Parken', 'Mindst 25 mister livet i luftangreb mod flere mål i Ukraine', 'Pengene ruller ind: Morten Hee har solgt sin lejlighed', 'Putins spritrute: Steget 120 procent', 'FH hasteindkalder: Lizette Risgaard anklages for upassende adfærd', 'Rockband genfødt efter 24 år', 'Pengeregn: Nu modtager særlig gruppe 5000 kroner', 'Sanne føler sig skamklippet: Vred på produktionen', 'Efter dårlig anmeldelse: Nu svarer han igen', 'Efter energikrise: Energikoncernen Andel mangedoblede sit overskud sidste år', 'Familie: Lige nu er der mange tanker', 'Udskyder undskyldning', 'Udskyder undskyldning', 'Pludselig ændring: Dommen er udsat', 'Blindt ind til kvalifikation: F1-racer i brand', 'Nyt om banegårdsaktion: Fire anholdt', 'HK overvejer ekstraordinær kongres om FH-formands fremtid', 'Skimmellignende væsker: Sur smiley til Netto', 'Anmeldelse om mand med gevær: Hold jer inden døre', "'Beck'-stjernen Stina Rautelin er død", 'Bygning overtændt: Tilkalder assistance', 'Lizette Risgaard går på orlov', 'Efter tyve år: Madonna udgiver skrottet musikvideo', '60-årig sigtet for hærværksbølge mod biler', 'Sælger 150 år gammel ejendom for to kroner', 'Mænd tiltalt for at planlægge knivangreb på gravid kvinde', 'Nyt overfald får christianitter til at frygte reel bandekrig', 'To kæmpe shows samme år: Sådan undgår jeg stress', 'Officielt: Vender tilbage i ikonisk rolle', 'Kovending: Dropper kæmpebøde til supermarked', 'Prinsessens nye titel: Ikke tjenstgørende', 'LIVE: FH holder krisemøde efter gramse-sager', 'Chok i kirkehus: To indbrud på to dage', 'Arla: Kæmpe prisfald på vej', 'FH indkalder til nyt krisemøde', 'Overrasker i retten: Bryder ud i sang', 'Nikolaj Jacobsen forlænger til 2030', 'Efter 25 år: Menneskelige rester identificeret', 'Søger vidner: 15-årig overfaldet', 'Harry Potter-stjerne gravid', 'Rystet storby: - Til at græde over', 'LIVE: FH holder krisemøde efter gramse-sager', "Minister: Slut med 'lovlig hash'", 'Brand i lejlighed i København', 'Amerikaner i Ukraine: Det er mere intenst end krigen mod terror', 'Stiktosset på rival: - Pikhoved', 'Mistede ufødt barn: Åbner op om sorgen', 'Politiets foto-fup: De må slet ikke', 'Konflikt mellem grupper af unge mænd førte til knivstik', 'To civile dræbt i hævdet ukrainsk angreb på russisk jord', 'Mary Fonden bløder millioner: Stort aktiesmæk', 'Bekræfter: Blev advaret i august 2021', 'Klimaramt landsby i Fiji forsøger at råbe verdensledere op', 'Kønsløs diva i Royal Arena', '- Faldt som en sten', 'Mystisk: Mangler 14 kvadratmeter', 'To personer bragt til hospitalet efter skyderi i Västerås', 'Åbner op om diagnose: Renser stearinlys om ...
# val_id_history: [('750497', ['9749224', '9749156', '9749224', '9748948', '9748980', '9748792', '9741033', '9748792', '9748792', '9748916', '9749076', '9749948', '9749947', '9749635', '9749444', '9748798', '9749397', '9748798', '9749916', '9745750', '9749668', '9745750', '9750296', '9745750', '9749916', '9750318', '9749886', '9749240', '9747411', '9749886', '9749886', '9751290', '9751220', '9751385', '9751020', '9751385', '9751135', '9751385', '9751385', '9750789', '9638857', '9751020', '9750687', '9749759', '9750687', '9750904', '9750687', '9751385', '9751411', '9749184', '9751411', '9749634', '9750995', '9751452', '9751411', '9751897', '9751850', '9751895', '9751866', '9744479', '9751866', '9751895', '9751895', '9747369', '9751895', '9751764', '9751670', '9744480', '9744479', '9744480', '9751688', '9751524', '9751932', '9751932', '9752155', '9752155', '9751975', '9751877', '9751975', '9751557', '9751771', '9751557', '9735795', '9751557', '9751778', '9751557', '9751975', '9752155', '9725978', '9752155', '9749182', '9752243', '9749938', '9752340', '9752323', '9749966', '9752155', '7787495', '9752155', '9751646', '9753177', '9753684', '9753097', '9753848', '9752685', '9754073', '9753668', '9753545', '9753811', '9752741', '9753811', '9753168', '9755102', '9754603', '9755027', '9754365', '9754520', '9738457', '9754520', '9753207', '9754520', '9754158', '9754520', '9753603', '9754520', '9754133', '9755285', '9753949', '9755088', '9628753', '9755088', '9754962', '9738457', '9756849', '9756287', '9756160', '9756782', '9756160', '9756287', '9735824', '9606510', '9755966', '9755966', '9757183', '9756361', '9757236', '9757191', '9753047', '9757054', '9757054', '9757622', '9758347', '9757599', '9757599', '9758347', '9757717', '9757891', '9757717', '9757717', '9757552', '9757876', '9758538', '9758538', '9757876', '9757552', '9758705', '9758717', '9758561', '9758777', '9758561', '9758717', '9759355', '9759595', '9759355', '9759355', '9759205', '9759355', '9759309', '9759309', '9760477', '9760288', '9760334', '9760962', '9760944', '9760521', '9760892', '9760521', '9760528', '9756169', '9760528', '9761784', '9761359', '9685856', '9761359', '9761315', '9761803', '9762689', '9759951', '9762689', '9762352', '7662811', '9762352', '9762377', '9757686', '9763120', '9761382', '9763120', '9762407', '9763120', '9764361', '9764070', '9764086', '9764070', '9764765', '9764617', '9765067', '9765169', '9765067', '9749080', '9764994', '9052240', '9764994', '9762952', '9764994', '9764813', '9758572', '9763400', '9757972', '9765438', '9764813', '9765067', '9764787', '9762387', '9765894', '9765641', '9765894', '9747803', '9765894', '9765582', '9765894', '9759476', '9754730', '9754042', '9766627', '9765955', '9766627', '9766620', '9766627', '9766625', '9766805', '9754042', '9766805', '9766805', '9767528', '9768515', '9766599', '9768515', '9768178', '9724944', '9768178', '9768150', '9747690', '9768150', '9767344', '9768150', '9746360', '9766603', '9749643', '9746360', '9767746', '9767957', '9768543', '9768451', '9768543', '9769135', '9768997', '9767534', '9768997', '9767534', '9768820', '9767534', '9768583', '9658292', '9768583', '9768583', '9767557', '9768583', '9767534', '9768793', '9769380', '9769347', '9767336', '9769414', '9769380', '9769387', '9768882', '9769356', '9769244', '9771919', '9771916', '9771919', '9771938', '9771919', '9771938', '9771919', '9769341', '9771919', '9771686', '9771919', '9772038', '9771948', '9771938', '9769370', '9770515', '9772221', '9770051', '9771113', '9772284', '9772185', '9772284', '9769341', '9772284', '9772284', '9770102', '9770102', '9772963', '9772830', '9773070', '9772830', '9772830', '9772813', '9772475', '9772475', '9769504', '9773341', '9773356', '9773296', '9738457', '9773943', '9773470', '9773943', '9773727', '9773612', '9773727', '9774187', '9773846', '9773846', '9695098', '9774363', '9774142', '9774363', '9769531', '9774363', '9774120', '9774363', '9774392', '9774352', '9774392', '9773846', '9774020', '9774297',  ...
# val_interaction: [('76658', 144772, '9788239', 'no'), ('76658', 144772, '9780702', 'no'), ('76658', 144772, '9553264', 'no'), ('76658', 144772, '9787499', 'no'), ('76658', 144772, '6741781', 'no'), ('76658', 144772, '9783042', 'yes'), ('76658', 144777, '9788521', 'no'), ('76658', 144777, '9786217', 'no'), ('76658', 144777, '9553264', 'no'), ('76658', 144777, '9788361', 'no')]
# test_information_history: [('41509', ['Kæmpe fiasko: Danmark flopper - IGEN!', 'Luksus-konkurs: Sådan pumpede de regnskaberne op', 'Luftlur: 500 kroner for én time', 'Luksus-konkurs: Sådan pumpede de regnskaberne op', '- Skide ærgerligt', 'Eksperter: - Ville være et prestigetab af en anden verden', 'Rusland afviser alt', 'Storbritannien: Russiske styrker er beordret fremad', 'Efterretning: Den russiske hær og Wagner-gruppen gør fremskridt i Bakhmut', 'Skud affyret i Aalborg: - Vi er rystede', 'Skamplet: Kæmpe dansk røvtur', 'Rusland afviser alt', 'Auktionshus løber fra aftaler: - Penge som gidsler', 'Luftlur: 500 kroner for én time', 'Skud affyret i Aalborg: - Vi er rystede', "Ny optagelse fra fan-slagsmål: - 'FC' er her!", 'Medie: Flere russiske kampfly skudt ned', 'Efterretning: Rusland må tage gamle kampvogne i brug', 'Storbritannien: Russiske styrker er beordret fremad', 'Stadig mystik om rystelser på Bornholm', 'Hold da op: Her slog de varmerekord', "Ny optagelse fra fan-slagsmål: - 'FC' er her!", 'LIVE: Nu er det afgjort!', 'Erdogan: Tyrkiets opposition står i ledtog med Biden', 'Erdogan lover fredelig magtoverdragelse ved eventuelt valgnederlag', 'Erdogan: Tyrkiets opposition står i ledtog med Biden', 'Freder Putin: Han er en helt', 'Skidt nyt for Zelenskyj', 'Overvejer at skifte Ruslands navn', 'Hemmelige dokumenter: Putin forbereder befolkning på nederlag', 'EU-topchef advarer Rusland: - Gammelt fjols', 'LIVE: Nu er det afgjort!', 'Bro-milliard: Betalte bilister for meget?', 'Harry Styles mishandlet i Horsens', 'PET: Det kan få konsekvenser', 'LIVE: Nu er det afgjort!', 'LIVE: Nu er det afgjort!', 'Medie: Flere russiske kampfly skudt ned', 'Nye efterretninger: Russisk eliteenhed får skrækvåben', 'Reagerer på fan-slagsmål: - Komplet idiotisk!', 'PET: Det kan få konsekvenser', 'Politikernes boligsager - Fusk, finter og fikumdik', 'Stadig mystik om rystelser på Bornholm', 'Stadig mystik om rystelser på Bornholm', 'Sverige vinder EM i vanvid og pop', 'Årets første kvartal slår rekord for indvandring til Danmark', 'Propfyldt psykiatrisk hospital: - En katastrofe venter efter krigen', "Ekspert: - Frygter 'åben vej'", 'Årets første kvartal slår rekord for indvandring til Danmark', 'Propfyldt psykiatrisk hospital: - En katastrofe venter efter krigen', 'Frankrig vil sende lette kampvogne til Ukraine i de kommende uger', 'Tyskland er klar med gigantisk støttepakke til Ukraine', 'Eksplosioner brager i Kiev under intensivt russisk luftangreb', 'Sex alle vegne: De hedeste streaming-nyheder', 'Søgsmål: Giuliani afkrævede kollega oralsex under telefonmøder', 'Trump sagsøger tidligere advokat', '27-årig tysk sygeplejerske dømt for drab på patienter', 'Hummelgaard: Det er ikke meningen!', 'Togkaos fra morgenstunden: Kører ikke flere steder i landet', 'Kraftig lejlighedsbrand: 20 evakueret', 'Elon Musk stævnet i sag om misbrug på Jeffrey Epsteins ø', 'Kraftig lejlighedsbrand: 20 evakueret', 'Skrankepavernes paradis: Styrelses-helvede eksploderer', 'Meldinger om nye lastbildemonstrationer', 'Elon Musk stævnet i sag om misbrug på Jeffrey Epsteins ø', 'Meldinger om nye lastbildemonstrationer', 'Derfor blokerer de: - Helt gak!', 'Teenagepiger befamlet i bus', 'Alvorlig ulykke', 'Satser: Ny A-kraft og 100 vindmøller', 'Sydkorea amok over dansk firma', "Politiet skrotter it-projekter: 'Meget bekymrende'", 'SLUT: Holger gør det!', "'Katastrofal sommer': Hjælp!", 'Stor mystik om Mette F.: Ministerchauffør raser', 'Putins inderkreds: Vestens fortabte håb', 'Sælger lejligheden: Forlanger millioner', 'SLUT: Holger gør det!', 'Skrankepavernes paradis: Styrelses-helvede eksploderer', 'Tidligere barnestjerne chokerer: - Folk blev krænket seksuelt foran mig', 'Stor mystik om Mette F.: Ministerchauffør raser', 'Passagerer i chok: Hitler-hyldest i Intercity-tog', "Aftale om USA's gældsloft kan lande senere på ugen", 'Usikkerhed om gældsloftet kan skabe uro på aktiemarkedet: Det kan du gøre', 'Renten presset op', 'Regn den selv ud: Kan du også skære 25% ...
# test_news_information: [('3000022', 'Hanks beskyldt for mishandling Tom Hanks har angiveligt mishandlet sin afdøde ekskone. Ny bog om skuespilleren bringer ubehagelige retsdokumenter frem Tom Hanks skulle angiveligt have mishandlet sin ekskone, Samantha Lewes.\nDet fremgår af en ny bog af forfatteren David Gardner, som har fået tilgang til en række hemmelige dokumenter fra retssager, hvor Samantha anklager Hanks verbalt at have mishandlet og ydmyget hende gennem en længere periode.\n- Min mand har gentagne gange mishandlet mig verbalt og ydmyget mig i mit hjem igennem de sidste 90 dage, siger Samantha Lewes ifølge SFGate.com.\n- Det har givet mig store følelsesmæssige problemer, skulle ekskonen være citeret for at sige i retsdokumenterne.\nSkilsmissen mellem Hanks og Lewes tog tre år, før den blev endeligt afsluttet i 1987.\nTilmed beskyldte ekskonen Tom Hanks for at have presset et urimeligt forlig ud af hende.\nSamantha Lewes døde af knoglekræft i 2002.'), ('3000063', "Bostrups aske spredt i Furesøen Studieværten blev mindet med glad festlighed Strålende sensommersol. Jazzede toner. Glas med champagne og hvidvin. Glade smil og varme kram.\nVidste man ikke bedre, lignede det en glad fest, som marinaen Furesøbad fredag eftermiddag lagde hus til.\nMen festen var i virkeligheden familiens og vennernes, herunder flere nuværende og tidligere tv-værter, varme farvel til den 67-årige journalist Steen Bostrup – i tre årtier hele Danmarks Mr. News. Sat i rammer, som festmennesket Bostrup ville have nydt at være en fysisk del af.\nHan døde pludseligt efter et ildebefindende i sit hjem for godt to uger siden, onsdag 6. september.\nSvæver på en røgfri sky\nIndenfor er et lille mindealter stillet op – to portrætbilleder af Mr. News, en langstilket rød rose og en barnetegning. Motivet er en smilende Steen Bostrup siddende på en lille sky. 'Jeg er en lykkelig x-ryger', har kunstneren, hans 11-årige barnebarn Anna Clara, ladet sin morfar sige – en sigende kommentar til den kendsgerning, at Steen Bostrup trods en hjerteoperation og sukkersyge ikke ville opgive smøgerne i levende live.\nSolskin er hans bidrag\n– I dag fejrer vi hans liv, mere end vi sørger over hans død, siger datteren, filminstruktør Charlotte Sachs Bostrup til Ekstra Bladet i et pause fra de mange kram og 'velkommen til', som hun deler ud til de mange, der er kommet for at sige et sidste farvel til hendes far.\nDagens strålende solskin tilskriver hun med et smil sin afdøde far:\n– Ja, nu har han jo direkte connection til vejrguderne, så det er hans bidrag i dag.\nKort forinden har hun sammen med blandt andet sin søster Camilla og Steens hustru, Charlotte Lawaetz, siddet i en lille båd, der gyngede blidt på Furesøs vover. For at sprede Steen Bostrups aske ud over søen.\n– Ja, nu er han i søen. Han ligger derude, siger hun og peger over det glitrende vand.\nEn lille privat stund\nEt øjeblik efter forlader hun diskret selskabet med sine børn, 15-årige Theodor og 11-årige Anna Clara, for sammen med Charlotte Lawaetz at få en helt privat stille stund med minderne om faderen, bedstefaderen og ægtemanden nede ved søbredden.\nSammen går de tilbage til de ventende gæster for at lade mindefesten starte. Med varme, personlige taler, med en komposition skrevet til lejligheden af Theodor, og et lille diasshow kreeret af Anna Clara. Og så et par fællessange – 'Jeg er havren' og 'Danmark nu blunder den lyse nat' – nøje udvalgt blandt Bostrups favoritter."), ('3000613', 'Jesper Olsen ramt af hjerneblødning Den tidligere danske landsholdsspiller i fodbold Jesper Olsen ligger på hospitalet på grund af en hjerneblødning. Jesper Olsen, der er noteret for 43 kampe på det danske fodboldlandshold, ligger i øjeblikket til observation på et hospital i Melbourne. I sidste uge blev 45-årige Olsen ramt af en hjerneblødning og straks bragt til hospitalet.\n- Han forbliver under observation, og han skal gennemgå flere test. Hans familie beder om, at deres privatliv bliver respekteret i denne periode, skr ...
# test_interaction: [('36744', 6451546, '9486080', 'unknown'), ('36744', 6451546, '9544385', 'unknown'), ('36744', 6451546, '9791334', 'unknown'), ('36744', 6451546, '9482394', 'unknown'), ('36744', 6451546, '9798958', 'unknown')]

# %%
import pandas as pd
import pickle
import os
from transformers import MarianMTModel, MarianTokenizer

# Function to load and inspect pickle files
def load_and_inspect(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

# Function to save the translated data
def save_translated_data(data, file_path):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# Function to translate text
def translate_text(texts, model, tokenizer):
    translated = []
    batch_size = 32
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        translated_batch = model.generate(**tokenizer(batch, return_tensors="pt", padding=True))
        translated_texts = [tokenizer.decode(t, skip_special_tokens=True) for t in translated_batch]
        translated.extend(translated_texts)
    return translated

# Initialize the model and tokenizer
model_name = 'Helsinki-NLP/opus-mt-da-en'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Load the data files
data_files = {
    'train_infor_his': './train/train_infor_his',
    'val_id_history': './val/val_id_history',
    'val_interaction': './val/val_interaction',
    'train_interaction': './train/train_interaction',
    'news_information': './news_infor',
    'test_information_history': './test/test_infor_his',
    'test_news_information': './test/test_news_infor',
    'test_interaction': './test/test_interaction'
}

# Create the translated folder if it doesn't exist
os.makedirs('./translated', exist_ok=True)

# Process each data file
for name, path in data_files.items():
    data = load_and_inspect(path)
    if name == 'train_infor_his' or name == 'test_information_history':
        # Translate dictionary values (list of texts)
        translated_data = {k: translate_text(v, model, tokenizer) for k, v in data.items()}
    elif name == 'train_interaction':
        # No translation needed for this format
        translated_data = data
    elif name == 'val_id_history':
        # No translation needed for this format
        translated_data = data
    elif name == 'val_interaction' or name == 'test_interaction':
        # No translation needed for this format
        translated_data = data
    elif name == 'news_information' or name == 'test_news_information':
        # Translate dictionary values (textual content)
        translated_data = {k: translate_text([v], model, tokenizer)[0] for k, v in data.items()}
    else:
        raise ValueError(f"Unsupported data type: {type(data)} for file: {name}")
    
    # Save the translated data
    save_translated_data(translated_data, f'./translated/{name}.pkl')

print("Translation and saving completed.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 53
#      50 data = load_and_inspect(path)
#      51 if name == 'train_infor_his' or name == 'test_information_history':
#      52     # Translate dictionary values (list of texts)
# ---> 53     translated_data = {k: translate_text(v, model, tokenizer) for k, v in data.items()}
#      54 elif name == 'train_interaction':
#      55     # No translation needed for this format
#      56     translated_data = data
#
# Cell In[5], line 53, in <dictcomp>(.0)
#      50 data = load_and_inspect(path)
#      51 if name == 'train_infor_his' or name == 'test_information_history':
#      52     # Translate dictionary values (list of texts)
# ---> 53     translated_data = {k: translate_text(v, model, tokenizer) for k, v in data.items()}
#      54 elif name == 'train_interaction':
#      55     # No translation needed for this format
#      56     translated_data = data
#
# Cell In[5], line 23, in translate_text(texts, model, tokenizer)
#      21 for i in range(0, len(texts), batch_size):
#      22     batch = texts[i:i+batch_size]
# ---> 23     translated_batch = model.generate(**tokenizer(batch, return_tensors="pt", padding=True))
#      24     translated_texts = [tokenizer.decode(t, skip_special_tokens=True) for t in translated_batch]
#      25     translated.extend(translated_texts)
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/transformers/generation/utils.py:1795, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1787     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1788         input_ids=input_ids,
#    1789         expand_size=generation_config.num_beams,
#    1790         is_encoder_decoder=self.config.is_encoder_decoder,
#    1791         **model_kwargs,
#    1792     )
#    1794     # 14. run beam sample
# -> 1795     result = self._beam_search(
#    1796         input_ids,
#    1797         beam_scorer,
#    1798         logits_processor=prepared_logits_processor,
#    1799         logits_warper=prepared_logits_warper,
#    1800         stopping_criteria=prepared_stopping_criteria,
#    1801         generation_config=generation_config,
#    1802         synced_gpus=synced_gpus,
#    1803         **model_kwargs,
#    1804     )
#    1806 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    1807     # 11. prepare beam search scorer
#    1808     beam_scorer = BeamSearchScorer(
#    1809         batch_size=batch_size,
#    1810         num_beams=generation_config.num_beams,
#    (...)
#    1816         max_length=generation_config.max_length,
#    1817     )
#
# File ~/.local/lib/python3.10/site-packages/transformers/generation/utils.py:2654, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, logits_warper, **model_kwargs)
#    2651     outputs = stack_model_outputs(outputs_per_sub_batch)
#    2653 else:  # Unchanged original behavior
# -> 2654     outputs = self(
#    2655         **model_inputs,
#    2656         return_dict=True,
#    2657         output_attentions=output_attentions,
#    2658         output_hidden_states=output_hidden_states,
#    2659     )
#    2661 if synced_gpus and this_peer_finished:
#    2662     cur_len = cur_len + 1
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/marian/modeling_marian.py:1400, in MarianMTModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1395     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1396         decoder_input_ids = shift_tokens_right(
#    1397             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1398         )
# -> 1400 outputs = self.model(
#    1401     input_ids,
#    1402     attention_mask=attention_mask,
#    1403     decoder_input_ids=decoder_input_ids,
#    1404     encoder_outputs=encoder_outputs,
#    1405     decoder_attention_mask=decoder_attention_mask,
#    1406     head_mask=head_mask,
#    1407     decoder_head_mask=decoder_head_mask,
#    1408     cross_attn_head_mask=cross_attn_head_mask,
#    1409     past_key_values=past_key_values,
#    1410     inputs_embeds=inputs_embeds,
#    1411     decoder_inputs_embeds=decoder_inputs_embeds,
#    1412     use_cache=use_cache,
#    1413     output_attentions=output_attentions,
#    1414     output_hidden_states=output_hidden_states,
#    1415     return_dict=return_dict,
#    1416 )
#    1417 lm_logits = self.lm_head(outputs[0]) + self.final_logits_bias
#    1419 masked_lm_loss = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/marian/modeling_marian.py:1195, in MarianModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1188     encoder_outputs = BaseModelOutput(
#    1189         last_hidden_state=encoder_outputs[0],
#    1190         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1191         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1192     )
#    1194 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1195 decoder_outputs = self.decoder(
#    1196     input_ids=decoder_input_ids,
#    1197     attention_mask=decoder_attention_mask,
#    1198     encoder_hidden_states=encoder_outputs[0],
#    1199     encoder_attention_mask=attention_mask,
#    1200     head_mask=decoder_head_mask,
#    1201     cross_attn_head_mask=cross_attn_head_mask,
#    1202     past_key_values=past_key_values,
#    1203     inputs_embeds=decoder_inputs_embeds,
#    1204     use_cache=use_cache,
#    1205     output_attentions=output_attentions,
#    1206     output_hidden_states=output_hidden_states,
#    1207     return_dict=return_dict,
#    1208 )
#    1210 if not return_dict:
#    1211     return decoder_outputs + encoder_outputs
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/marian/modeling_marian.py:995, in MarianDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     982     layer_outputs = self._gradient_checkpointing_func(
#     983         decoder_layer.__call__,
#     984         hidden_states,
#    (...)
#     992         use_cache,
#     993     )
#     994 else:
# --> 995     layer_outputs = decoder_layer(
#     996         hidden_states,
#     997         attention_mask=attention_mask,
#     998         encoder_hidden_states=encoder_hidden_states,
#     999         encoder_attention_mask=encoder_attention_mask,
#    1000         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1001         cross_attn_layer_head_mask=(
#    1002             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1003         ),
#    1004         past_key_value=past_key_value,
#    1005         output_attentions=output_attentions,
#    1006         use_cache=use_cache,
#    1007     )
#    1008 hidden_states = layer_outputs[0]
#    1010 if use_cache:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/marian/modeling_marian.py:434, in MarianDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     432 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     433 hidden_states = residual + hidden_states
# --> 434 hidden_states = self.encoder_attn_layer_norm(hidden_states)
#     436 # add cross-attn to positions 3,4 of present_key_value tuple
#     437 present_key_value = present_key_value + cross_attn_present_key_value
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/normalization.py:189, in LayerNorm.forward(self, input)
#     188 def forward(self, input: Tensor) -> Tensor:
# --> 189     return F.layer_norm(
#     190         input, self.normalized_shape, self.weight, self.bias, self.eps)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/functional.py:2486, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2482 if has_torch_function_variadic(input, weight, bias):
#    2483     return handle_torch_function(
#    2484         layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2485     )
# -> 2486 return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#
# KeyboardInterrupt:
